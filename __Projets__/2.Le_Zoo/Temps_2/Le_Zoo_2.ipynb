# %% [markdown]
# # <center> LE ZOO : Création des tables et insertion de valeurs </center>

# %% [markdown]
# Voici une solution de MCD concernant la gestion des animaux par l'association ADER (Voir travail précédent).

# %%
# %reload_ext mocodo_magic

# %%
# %%mocodo --mld
# DESCENDRE, 02 ANIMAL,0N ANIMAL
# VISITER, 0N VETERINAIRE, 0N ANIMAL: bulletin_visite, date_visite
# VETERINAIRE:id_veto,nom_veto,prenom_veto,adr_veto,tel_veto,tel_port_veto
# SPECIALISER, 0N ESPECE,0N VETERINAIRE
# :
#
# HEBERGER, 0N ANIMAL, 0N PARC: motif_presence,date_arrivee,date_depart
# ANIMAL:ref_animal,nom_animal,sexe,date_naissance,date_deces,cause_deces
# DF1, _11 ANIMAL, 0N> ESPECE
# ESPECE:id_espece,nom espece,nb_monde
#
#
# PARC: id_parc, nom_parc, adr_parc,tel_parc, superficie, date_entree, date_exclu
# PROVENIR, 0N PAYS, 01 ANIMAL
# PAYS:id_pays, nom_pays
# VIVRE_LIBRE, 0N PAYS, 0N ESPECE
# :
#
# CONTROLER, 0N CONTROLEUR, 0N PARC:compte_rendu, date_cr
# CONTROLEUR : id_controleur, nom_controleur,prenom_controleur, adr_controleur,tel_controleur
# DF2, _11 PAYS, 1N> CONTINENT
# CONTINENT:id_continent, nom_continent
# MEMBRE:id_membre,nom_membre,prenom_membre,adr_membre,somme_versee
# Out:
# <html>
# <head>
# <meta charset='utf-8'>
# <style>
#   #mld .relation { font-variant: small-caps; font-weight: bold }
#   #mld .primary { text-decoration: underline }
#   #mld .foreign { font-style: oblique }
#   #mld .normal { }
# </style>
# </head>
# <body>
# <div id='mld'>
# <div>
#   <span class='relation'>DESCENDRE</span> (
#     <span class='foreign primary'>id_espece</span>,
#     <span class='foreign primary'>ref_animal</span>,
#     <span class='foreign primary'>id_espece.1</span>,
#     <span class='foreign primary'>ref_animal.1</span>
#   )
# </div>
# <div>
#   <span class='relation'>VISITER</span> (
#     <span class='foreign primary'>id_veto</span>,
#     <span class='foreign primary'>id_espece</span>,
#     <span class='foreign primary'>ref_animal</span>,
#     <span class='normal'>bulletin_visite</span>,
#     <span class='normal'>date_visite</span>
#   )
# </div>
# <div>
#   <span class='relation'>VETERINAIRE</span> (
#     <span class='primary'>id_veto</span>,
# ...

# %% [markdown]
# ## Travail à faire

# %% [markdown]
# En vous aidant de l'outil mocodo en ligne, https://www.mocodo.net/ , créer 2 scripts au format `.sql`:
# * Un script contenant la création de toutes les tables présentes ci-dessus, avec les attributs. On veillera à utiliser lestypes de données les plus pertinents pour chacun d'entre eux.
# * Un script permettant de peupler les tables avec des exemples de votre choix. En particulier, on insérera :
#     * Au moins 20 animaux et 10 espèces différentes
#     * 4 parcs
#     * Tous les continents
#     * Au moins une dizaine de pays
#     * 5 membres bienfaiteurs
#     * 3 vétérinaires
#     * 5 contôleurs
#     * 2 bulletins de visites (avec leur compte rendu)
#     * 2 compte rendus de contôle
